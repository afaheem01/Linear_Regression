# %% [markdown]
# <a href="https://colab.research.google.com/github/afaheem01/Linear_Regression/blob/main/Regression_analysis_on_Mobile_phone_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_csv("/content/mobile phone price prediction.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                  Name  Rating  Spec_score  \
# 0           0                 Samsung Galaxy F14 5G    4.65          68
# 1           1                    Samsung Galaxy A11    4.20          63
# 2           2                    Samsung Galaxy A13    4.30          75
# 3           3                    Samsung Galaxy F23    4.10          73
# 4           4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
#
#                        No_of_sim       Ram            Battery     Display  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE,   4 GB RAM  6000 mAh Battery   6.6 inches
# 1      Dual Sim, 3G, 4G, VoLTE,   2 GB RAM  4000 mAh Battery   6.4 inches
# 2      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery   6.6 inches
# 3      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM   6000 mAh Battery  6.4 inches
# 4      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery   6.5 inches
#
#                                               Camera  \
# ...

# %%
# Check the dataset info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1370 non-null   int64
#  1   Name               1370 non-null   object
#  2   Rating             1370 non-null   float64
#  3   Spec_score         1370 non-null   int64
#  4   No_of_sim          1370 non-null   object
#  5   Ram                1370 non-null   object
#  6   Battery            1370 non-null   object
#  7   Display            1370 non-null   object
#  8   Camera             1370 non-null   object
#  9   External_Memory    1370 non-null   object
#  10  Android_version    927 non-null    object
#  11  Price              1370 non-null   object
#  12  company            1370 non-null   object
#  13  Inbuilt_memory     1351 non-null   object
#  14  fast_charging      1281 non-null   object
#  15  Screen_resolution  1368 non-null   object
# ...

# %%
# check the null values.

df.isnull().sum()
# Out:
# Unnamed: 0             0
# Name                   0
# Rating                 0
# Spec_score             0
# No_of_sim              0
# Ram                    0
# Battery                0
# Display                0
# Camera                 0
# External_Memory        0
# Android_version      443
# Price                  0
# company                0
# Inbuilt_memory        19
# fast_charging         89
# Screen_resolution      2
# Processor             28
# Processor_name         0
# dtype: int64

# %%
df.shape
# Out:
# (1370, 18)

# %%
df['Battery'] = df['Battery'].str.split(' ', expand=True)[0].astype(float)

# %%
df['Display'] = df["Display"].str.split(" ", expand=True)[0].astype(float)

# %%
df['Ram'].unique()
# Out:
# array(['4 GB RAM', '2 GB RAM', '6 GB RAM', '8 GB RAM', '12 GB RAM',
#        '1 GB RAM', '3 GB RAM', '16 GB RAM', 'Helio G90T', '24 GB RAM',
#        '18 GB RAM', '1.5 GB RAM', '128 GB inbuilt',
#        '6000 mAh Battery with 22.5W Fast Charging', '256 GB inbuilt',
#        '512 GB inbuilt'], dtype=object)

# %%
patterns = ['Helio G90T', '6000 mAh Battery with 22.5W Fast Charging']
df = df[~df['Ram'].str.contains('|'.join(patterns))]

value_count = df["Ram"].value_counts()
print(value_count)
# Out:
# Ram
# 8 GB RAM          528
# 4 GB RAM          253
# 12 GB RAM         246
# 6 GB RAM          214
# 16 GB RAM          41
# 3 GB RAM           38
# 2 GB RAM           22
# 256 GB inbuilt      8
# 128 GB inbuilt      7
# 18 GB RAM           4
# 512 GB inbuilt      3
# 24 GB RAM           2
# 1 GB RAM            1
# 1.5 GB RAM          1
# Name: count, dtype: int64

# %%
df["Ram"] = df["Ram"].str.split(' ', expand=True)[0].astype(float)

# %%
df["Ram"]
# Out:
# 0        4.0
# 1        2.0
# 2        4.0
# 3        4.0
# 4        4.0
#         ...
# 1365     4.0
# 1366     8.0
# 1367     6.0
# 1368     6.0
# 1369    12.0
# Name: Ram, Length: 1368, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0                                  Name  Rating  Spec_score  \
# 0           0                 Samsung Galaxy F14 5G    4.65          68
# 1           1                    Samsung Galaxy A11    4.20          63
# 2           2                    Samsung Galaxy A13    4.30          75
# 3           3                    Samsung Galaxy F23    4.10          73
# 4           4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
#
#                        No_of_sim  Ram  Battery  Display  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE,   4.0   6000.0      6.6
# 1      Dual Sim, 3G, 4G, VoLTE,   2.0   4000.0      6.4
# 2      Dual Sim, 3G, 4G, VoLTE,   4.0   5000.0      6.6
# 3      Dual Sim, 3G, 4G, VoLTE,   4.0   6000.0      6.4
# 4      Dual Sim, 3G, 4G, VoLTE,   4.0   5000.0      6.5
#
#                                               Camera  \
# 0    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
# ...

# %%
# Dropping the irrevelant columns

df.drop(columns=["Unnamed: 0", "Name", "Android_version"], axis=1, inplace=True)

# %%
df
# Out:
#       Rating  Spec_score                            No_of_sim   Ram  Battery  \
# 0       4.65          68        Dual Sim, 3G, 4G, 5G, VoLTE,    4.0   6000.0
# 1       4.20          63            Dual Sim, 3G, 4G, VoLTE,    2.0   4000.0
# 2       4.30          75            Dual Sim, 3G, 4G, VoLTE,    4.0   5000.0
# 3       4.10          73            Dual Sim, 3G, 4G, VoLTE,    4.0   6000.0
# 4       4.10          69            Dual Sim, 3G, 4G, VoLTE,    4.0   5000.0
# ...      ...         ...                                  ...   ...      ...
# 1365    4.05          75        Dual Sim, 3G, 4G, 5G, VoLTE,    4.0   5000.0
# 1366    4.10          80            Dual Sim, 3G, 4G, VoLTE,    8.0   5000.0
# 1367    4.00          80        Dual Sim, 3G, 4G, 5G, VoLTE,    6.0   5000.0
# 1368    4.50          79        Dual Sim, 3G, 4G, 5G, VoLTE,    6.0   5000.0
# 1369    4.65          93  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G,   12.0   4600.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Rating                0
# Spec_score            0
# No_of_sim             0
# Ram                   0
# Battery               0
# Display               0
# Camera                0
# External_Memory       0
# Price                 0
# company               0
# Inbuilt_memory       18
# fast_charging        88
# Screen_resolution     0
# Processor            27
# Processor_name        0
# dtype: int64

# %%
# Fill the null values using simple imputer.
from sklearn.impute import SimpleImputer
imputer= SimpleImputer()

# %%
df["Inbuilt_memory"]= imputer.fit_transform(df[["Inbuilt_memory"]]).ravel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-dcef39f1603d> in <cell line: 1>()
# ----> 1 df["Inbuilt_memory"]= imputer.fit_transform(df[["Inbuilt_memory"]]).ravel()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
# ...

# %%
df['Inbuilt_memory'] = df['Inbuilt_memory'].str.extract(r'(\d+)').astype(float)

# %%
df['fast_charging'] = df['fast_charging'].str.extract(r'(\d+)').astype(float)

# %%
df["Inbuilt_memory"]= imputer.fit_transform(df[["Inbuilt_memory"]]).ravel()

# %%
df['fast_charging']= imputer.fit_transform(df[['fast_charging']]).ravel()

# %%
df['Processor'].value_counts()
# Out:
# Processor
#  Octa Core              1237
#  Octa Core Processor      75
#  Quad Core                11
#  1.6 GHz Processor         3
#  Deca Core                 3
#  2 GHz Processor           2
#  Nine-Cores                2
#  Nine Core                 2
#  Nine Cores                2
#  1.8 GHz Processor         1
#  Deca Core Processor       1
#  1.3 GHz Processor         1
#  2.3 GHz Processor         1
# Name: count, dtype: int64

# %%
df['Processor'] = df['Processor'].str.extract(r'(\d+)').astype(float)

# %%
df['Processor']=imputer.fit_transform(df[['Processor']],).ravel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-52e2d909085f> in <cell line: 1>()
# ----> 1 df['Processor']=imputer.fit_transform(df[['Processor']]).ravel()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
# ...

# %%
df['Processor']
# Out:
# 0        Octa Core Processor
# 1          1.8 GHz Processor
# 2            2 GHz Processor
# 3                  Octa Core
# 4                  Octa Core
#                 ...
# 1365               Octa Core
# 1366               Octa Core
# 1367               Octa Core
# 1368               Octa Core
# 1369               Octa Core
# Name: Processor, Length: 1368, dtype: object

# %%
df.isnull().sum()
# Out:
# Rating                0
# Spec_score            0
# No_of_sim             0
# Ram                   0
# Battery               0
# Display               0
# Camera                0
# External_Memory       0
# Price                 0
# company               0
# Inbuilt_memory        0
# fast_charging         0
# Screen_resolution     0
# Processor            27
# Processor_name        0
# dtype: int64

# %%
# drop processor_name since it is getting duplicated from processor
df.drop(["Processor_name"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Rating  Spec_score                      No_of_sim  Ram  Battery  Display  \
# 0    4.65          68  Dual Sim, 3G, 4G, 5G, VoLTE,   4.0   6000.0      6.6
# 1    4.20          63      Dual Sim, 3G, 4G, VoLTE,   2.0   4000.0      6.4
# 2    4.30          75      Dual Sim, 3G, 4G, VoLTE,   4.0   5000.0      6.6
# 3    4.10          73      Dual Sim, 3G, 4G, VoLTE,   4.0   6000.0      6.4
# 4    4.10          69      Dual Sim, 3G, 4G, VoLTE,   4.0   5000.0      6.5
#
#                                               Camera  \
# 0    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
# 2            50 MP Quad Rear &amp; 8 MP Front Camera
# 3           48 MP Quad Rear &amp; 13 MP Front Camera
# 4  13 MP + 2 MP + 2 MP Triple Rear &amp; 5 MP Fro...
#
#                       External_Memory   Price  company  Inbuilt_memory  \
# 0    Memory Card Supported, upto 1 TB   9,999  Samsung           128.0
# ...

# %%
df["Processor"].value_counts()
# Out:
# Processor
#  Octa Core              1237
#  Octa Core Processor      75
#  Quad Core                11
#  1.6 GHz Processor         3
#  Deca Core                 3
#  2 GHz Processor           2
#  Nine-Cores                2
#  Nine Core                 2
#  Nine Cores                2
#  1.8 GHz Processor         1
#  Deca Core Processor       1
#  1.3 GHz Processor         1
#  2.3 GHz Processor         1
# Name: count, dtype: int64

# %%
df['Processor'].unique()
# Out:
# array([' Octa Core Processor', ' 1.8 GHz Processor', ' 2 GHz Processor',
#        ' Octa Core', nan, ' Quad Core', ' Nine-Cores', ' Nine Core',
#        ' Nine Cores', ' Deca Core Processor', ' 1.3 GHz Processor',
#        ' 1.6 GHz Processor', ' 2.3 GHz Processor', ' Deca Core'],
#       dtype=object)

# %%
processor_mapping = {
    'Octa Core': 'Octa Core',
    'Octa Core Processor': 'Octa Core',
    'Quad Core': 'Quad Core',
    'Deca Core': 'Deca Core',
    'Deca Core Processor': 'Deca Core',
    'Nine-Cores': 'Nine Core',
    'Nine Core': 'Nine Core',
    'Nine Cores': 'Nine Core',
    '1.6 GHz Processor': '1.6 GHz Processor',
    '2 GHz Processor': '2 GHz Processor',
    '1.8 GHz Processor': '1.8 GHz Processor',
    '1.3 GHz Processor': '1.3 GHz Processor',
    '2.3 GHz Processor': '2.3 GHz Processor'
}
df['Processor'] = df['Processor'].replace(processor_mapping)

# %%
df["Processor"].value_counts()
# Out:
# Processor
#  Octa Core              1237
#  Octa Core Processor      75
#  Quad Core                11
#  1.6 GHz Processor         3
#  Deca Core                 3
#  2 GHz Processor           2
#  Nine-Cores                2
#  Nine Core                 2
#  Nine Cores                2
#  1.8 GHz Processor         1
#  Deca Core Processor       1
#  1.3 GHz Processor         1
#  2.3 GHz Processor         1
# Name: count, dtype: int64

# %%
df["No_of_sim"].value_counts()
# Out:
# No_of_sim
# Dual Sim, 3G, 4G, 5G, VoLTE,             818
# Dual Sim, 3G, 4G, VoLTE,                 417
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G,        91
# Single Sim, 3G, 4G, 5G, VoLTE,            20
# Dual Sim, 3G, 4G,                         13
# Single Sim, 3G, 4G, VoLTE,                 6
# No Sim Supported,                          1
# Single Sim, 3G, 4G, 5G, VoLTE, Vo5G,       1
# Dual Sim, 3G, VoLTE,                       1
# Name: count, dtype: int64

# %%
df['No_of_sim'] = df['No_of_sim'].str.strip()
sim_importance_mapping = {
    'No Sim Supported,': 0,
    'Single Sim, 3G, 4G,': 1,
    'Dual Sim, 3G, VoLTE,': 2,
    'Single Sim, 3G, 4G, VoLTE,': 3,
    'Dual Sim, 3G, 4G,': 4,
    'Dual Sim, 3G, 4G, VoLTE,': 5,
    'Single Sim, 3G, 4G, 5G, VoLTE,': 6,
    'Dual Sim, 3G, 4G, 5G, VoLTE,': 7,
    'Single Sim, 3G, 4G, 5G, VoLTE, Vo5G,': 8,
    'Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G,': 9
}

# Replace the values in the column based on the mapping
df['Sim_encoded'] = df['No_of_sim'].replace(sim_importance_mapping)

# %%
df.head(2)
# Out:
#    Rating  Spec_score                     No_of_sim  Ram  Battery  Display  \
# 0    4.65          68  Dual Sim, 3G, 4G, 5G, VoLTE,  4.0   6000.0      6.6
# 1    4.20          63      Dual Sim, 3G, 4G, VoLTE,  2.0   4000.0      6.4
#
#                                               Camera  \
# 0    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
#
#                       External_Memory  Price  company  Inbuilt_memory  \
# 0    Memory Card Supported, upto 1 TB  9,999  Samsung           128.0
# 1  Memory Card Supported, upto 512 GB  9,990  Samsung            32.0
#
#    fast_charging                              Screen_resolution  \
# 0           25.0   2408 x 1080 px Display with Water Drop Notch
# 1           15.0          720 x 1560 px Display with Punch Hole
#
#               Processor  Sim_encoded
# 0   Octa Core Processor            7
# 1     1.8 GHz Processor            5

# %%
df.drop(['No_of_sim'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    Rating  Spec_score  Ram  Battery  Display  \
# 0    4.65          68  4.0   6000.0      6.6
# 1    4.20          63  2.0   4000.0      6.4
#
#                                               Camera  \
# 0    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
#
#                       External_Memory  Price  company  Inbuilt_memory  \
# 0    Memory Card Supported, upto 1 TB  9,999  Samsung           128.0
# 1  Memory Card Supported, upto 512 GB  9,990  Samsung            32.0
#
#    fast_charging                              Screen_resolution  \
# 0           25.0   2408 x 1080 px Display with Water Drop Notch
# 1           15.0          720 x 1560 px Display with Punch Hole
#
#               Processor  Sim_encoded
# 0   Octa Core Processor            7
# 1     1.8 GHz Processor            5

# %%
df["Camera"].value_counts()
# Out:
# Camera
# 50 MP + 2 MP Dual Rear &amp; 8 MP Front Camera                             81
# Foldable Display, Dual Display                                             69
# 50 MP + 8 MP + 2 MP Triple Rear &amp; 16 MP Front Camera                   61
# 64 MP + 8 MP + 2 MP Triple Rear &amp; 16 MP Front Camera                   40
# 50 MP + 2 MP Dual Rear &amp; 16 MP Front Camera                            31
#                                                                            ..
# 54 MP + 8 MP + 2 MP Triple Rear &amp; 16 MP Front Camera                    1
# 160 MP + 50 MP + 2 MP Triple Rear &amp; 50 MP + 2 MP Dual Front Camera      1
# 108 MP + 32 MP + 12 MP Triple Rear &amp; 50 MP + 2 MP Dual Front Camera     1
# 50 MP + 16 MP + 8 MP Triple Rear &amp; 32 MP + 8 MP Dual Front Camera       1
# 50 MP + 5 MP + 2 MP Triple Rear &amp; 32 MP Front Camera                    1
# Name: count, Length: 345, dtype: int64

# %%
patterns = ['Foldable Display, Dual Display']
df = df[~df['Camera'].str.contains('|'.join(patterns))]

# %%
df['Camera'].value_counts()
# Out:
# Camera
# 50 MP + 2 MP Dual Rear &amp; 8 MP Front Camera               81
# 50 MP + 8 MP + 2 MP Triple Rear &amp; 16 MP Front Camera     61
# 64 MP + 8 MP + 2 MP Triple Rear &amp; 16 MP Front Camera     40
# 50 MP + 2 MP Dual Rear &amp; 16 MP Front Camera              31
# 50 MP + 8 MP Dual Rear &amp; 16 MP Front Camera              24
#                                                              ..
# 8 MP + 2 MP + 0.3 MP Triple Rear &amp; 8 MP Front Camera      1
# 50 MP + 2 MP + 0.3 MP Triple Rear &amp; 8 MP Front Camera     1
# 50 MP + 12 MP + 5 MP Triple Rear &amp; 12 MP Front Camera     1
# 50.3 MP Quad Rear &amp; 32 MP Front Camera                    1
# 50 MP + 5 MP + 2 MP Triple Rear &amp; 32 MP Front Camera      1
# Name: count, Length: 344, dtype: int64

# %%
def extract_back_camera_mp(camera_str):
    back_camera_part = re.search(r'([\d\s\+MP]+Rear)', camera_str)
    if back_camera_part:
        back_cameras = re.findall(r'(\d+) MP', back_camera_part.group(1))
        return sum(map(int, back_cameras))
    return 0

# Function to extract the front camera MP
def extract_front_camera_mp(camera_str):
    front_camera_part = re.search(r'(\d+) MP Front', camera_str)
    if front_camera_part:
        return int(front_camera_part.group(1))
    return 0

# Apply the functions to create new columns
df['Front_Camera_MP'] = df['Camera'].apply(extract_front_camera_mp)

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
df['Processor_Encoded'] = encoder.fit_transform(df[['Processor']])

# %%
df.head(2)
# Out:
#    Rating  Spec_score  Ram  Battery  Display  \
# 0    4.65          68  4.0   6000.0      6.6
# 1    4.20          63  2.0   4000.0      6.4
#
#                                               Camera  \
# 0    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
#
#                       External_Memory  Price  company  Inbuilt_memory  \
# 0    Memory Card Supported, upto 1 TB  9,999  Samsung           128.0
# 1  Memory Card Supported, upto 512 GB  9,990  Samsung            32.0
#
#    fast_charging                              Screen_resolution  \
# 0           25.0   2408 x 1080 px Display with Water Drop Notch
# 1           15.0          720 x 1560 px Display with Punch Hole
#
#               Processor  Sim_encoded  Front_Camera_MP  Processor_Encoded
# 0   Octa Core Processor            7               13               10.0
# 1     1.8 GHz Processor            5                8                2.0

# %%
def extract_resolution_pixels(resolution_str):
    match = re.search(r'(\d+) x (\d+)', resolution_str)
    if match:
        width, height = map(int, match.groups())
        return width * height
    return 0

# Apply the function to create a new column for total pixels
df['Total_Pixels'] = df['Screen_resolution'].apply(extract_resolution_pixels)

# %%
df.head()
# Out:
#    Rating  Spec_score  Ram  Battery  Display  \
# 0    4.65          68  4.0   6000.0      6.6
# 1    4.20          63  2.0   4000.0      6.4
# 2    4.30          75  4.0   5000.0      6.6
# 3    4.10          73  4.0   6000.0      6.4
# 4    4.10          69  4.0   5000.0      6.5
#
#                                               Camera  \
# 0    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
# 2            50 MP Quad Rear &amp; 8 MP Front Camera
# 3           48 MP Quad Rear &amp; 13 MP Front Camera
# 4  13 MP + 2 MP + 2 MP Triple Rear &amp; 5 MP Fro...
#
#                       External_Memory   Price  company  Inbuilt_memory  \
# 0    Memory Card Supported, upto 1 TB   9,999  Samsung           128.0
# 1  Memory Card Supported, upto 512 GB   9,990  Samsung            32.0
# 2    Memory Card Supported, upto 1 TB  11,999  Samsung            64.0
# 3    Memory Card Supported, upto 1 TB  11,999  Samsung            64.0
# ...

# %%
df.drop(['Screen_resolution'],axis=1,inplace=True)

# %%
df.drop(columns=['Camera','External_Memory','Processor'],inplace=True)

# %%
df.head(2)
# Out:
#    Rating  Spec_score  Ram  Battery  Display  Price  company  Inbuilt_memory  \
# 0    4.65          68  4.0   6000.0      6.6  9,999  Samsung           128.0
# 1    4.20          63  2.0   4000.0      6.4  9,990  Samsung            32.0
#
#    fast_charging  Sim_encoded  Front_Camera_MP  Processor_Encoded  \
# 0           25.0            7               13               10.0
# 1           15.0            5                8                2.0
#
#    Total_Pixels
# 0       2600640
# 1       1123200

# %%
company_mapping= {
    'Apple': 1,
    'Samsung': 2,
    'Huawei': 3,
    'Xiaomi': 4,
    'Oppo': 5,
    'IQOO': 6,
    'iQOO':6,
    'Vivo': 7,
    'OnePlus': 8,
    'Google': 9,
    'Motorola': 10,
    'Realme': 11,
    'Asus': 12,
    'Honor': 13,
    'Nokia': 14,
    'Sony': 15,
    'LG': 16,
    'Lenovo': 17,
    'TCL': 18,
    'Lava': 19,
    'itel': 20,
    'Tecno': 21,
    'Gionee': 22,
    'Nothing': 23,
    'Coolpad': 24,
    'POCO': 25,
    'Poco': 25,
    'Itel': 20,
    'OPPO': 5

}

df['company_name'] = df['company'].replace(company_mapping)

# %%
df.drop(["company"], axis=1, inplace= True)

# %%
df.head(2)
# Out:
#    Rating  Spec_score  Ram  Battery  Display  Price  Inbuilt_memory  \
# 0    4.65          68  4.0   6000.0      6.6  9,999           128.0
# 1    4.20          63  2.0   4000.0      6.4  9,990            32.0
#
#    fast_charging  Sim_encoded  Front_Camera_MP  Processor_Encoded  \
# 0           25.0            7               13               10.0
# 1           15.0            5                8                2.0
#
#    Total_Pixels  company_name
# 0       2600640             2
# 1       1123200             2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1299 entries, 0 to 1368
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             1299 non-null   float64
#  1   Spec_score         1299 non-null   int64
#  2   Ram                1299 non-null   float64
#  3   Battery            1299 non-null   float64
#  4   Display            1299 non-null   float64
#  5   Price              1299 non-null   object
#  6   Inbuilt_memory     1299 non-null   float64
#  7   fast_charging      1299 non-null   float64
#  8   Sim_encoded        1299 non-null   int64
#  9   Front_Camera_MP    1299 non-null   int64
#  10  Processor_Encoded  1275 non-null   float64
#  11  Total_Pixels       1299 non-null   int64
#  12  company_name       1299 non-null   int64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 142.1+ KB

# %%
df["Price"]
# Out:
# 0        9,999
# 1        9,990
# 2       11,999
# 3       11,999
# 4       11,999
#          ...
# 1364    19,990
# 1365    18,999
# 1366    24,990
# 1367    23,990
# 1368    22,499
# Name: Price, Length: 1299, dtype: object

# %%
df['Price'] = df['Price'].str.replace(',', '').astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1299 entries, 0 to 1368
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             1299 non-null   float64
#  1   Spec_score         1299 non-null   int64
#  2   Ram                1299 non-null   float64
#  3   Battery            1299 non-null   float64
#  4   Display            1299 non-null   float64
#  5   Price              1299 non-null   int64
#  6   Inbuilt_memory     1299 non-null   float64
#  7   fast_charging      1299 non-null   float64
#  8   Sim_encoded        1299 non-null   int64
#  9   Front_Camera_MP    1299 non-null   int64
#  10  Processor_Encoded  1275 non-null   float64
#  11  Total_Pixels       1299 non-null   int64
#  12  company_name       1299 non-null   int64
# dtypes: float64(7), int64(6)
# memory usage: 142.1 KB

# %%
df["Price"]
# Out:
# 0        9999
# 1        9990
# 2       11999
# 3       11999
# 4       11999
#         ...
# 1364    19990
# 1365    18999
# 1366    24990
# 1367    23990
# 1368    22499
# Name: Price, Length: 1299, dtype: int64

# %%
df.isnull().sum()
# Out:
# Rating                0
# Spec_score            0
# Ram                   0
# Battery               0
# Display               0
# Price                 0
# Inbuilt_memory        0
# fast_charging         0
# Sim_encoded           0
# Front_Camera_MP       0
# Processor_Encoded    24
# Total_Pixels          0
# company_name          0
# dtype: int64

# %%
df["Processor_Encoded"]= imputer.fit_transform(df[["Processor_Encoded"]]).ravel()

# %%
df.isnull().sum()
# Out:
# Rating               0
# Spec_score           0
# Ram                  0
# Battery              0
# Display              0
# Price                0
# Inbuilt_memory       0
# fast_charging        0
# Sim_encoded          0
# Front_Camera_MP      0
# Processor_Encoded    0
# Total_Pixels         0
# company_name         0
# dtype: int64

# %%
x= df.drop(columns=["Price"])
y= df["Price"]

# %%
x.head()
# Out:
#    Rating  Spec_score  Ram  Battery  Display  Inbuilt_memory  fast_charging  \
# 0    4.65          68  4.0   6000.0      6.6           128.0      25.000000
# 1    4.20          63  2.0   4000.0      6.4            32.0      15.000000
# 2    4.30          75  4.0   5000.0      6.6            64.0      25.000000
# 3    4.10          73  4.0   6000.0      6.4            64.0      52.782434
# 4    4.10          69  4.0   5000.0      6.5            64.0      15.000000
#
#    Sim_encoded  Front_Camera_MP  Processor_Encoded  Total_Pixels  company_name
# 0            7               13               10.0       2600640             2
# 1            5                8                2.0       1123200             2
# 2            5                8                3.0       2600640             2
# 3            5               13                9.0       1152000             2
# 4            5                5                9.0       1152000             2

# %%
y.head()
# Out:
# 0     9999
# 1     9990
# 2    11999
# 3    11999
# 4    11999
# Name: Price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.25, random_state=42)

# %%
x_train.shape
# Out:
# (974, 12)

# %%
x_test.shape
# Out:
# (325, 12)

# %%
y_train.shape
# Out:
# (974,)

# %%
y_test.shape
# Out:
# (325,)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Print the coeff and intercepts

print("Coefficients: ", regression.coef_)
print("intercept: ", regression.intercept_)
# Out:
# Coefficients:  [-3.74128703e+03  9.23092694e+02  8.09868967e+01 -5.92384025e+00
#  -2.52684746e+03  8.35933721e+01  5.24108478e+01  2.46083146e+02
#  -2.33803579e+02 -9.36726409e+02  6.25750395e-03 -2.31792680e+02]
# intercept:  -1147.891638988076

# %%
y_pred= regression.predict(x_test)

# %%
# Find R2 score, mae, mse and rmse

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae= mean_absolute_error(y_test, y_pred)
mse= mean_squared_error(y_test,y_pred)
rmse= np.sqrt(mse)
r2score= r2_score(y_test, y_pred)

print("mae: ", mae)
print("mse: ", mse)
print("RMSE: ", rmse)
print("r2_score: ", r2_score)
# Out:
# mae:  11557.219386187753
# mse:  246186347.88662922
# RMSE:  15690.326570426418
# r2_score:  <function r2_score at 0x788d66945e10>

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train, x_train).fit()

# %%
prediction = model.predict(x_test)
print(prediction)
# Out:
# 1301    29382.269452
# 622     30831.475132
# 1229    46976.381086
# 770     25929.523126
# 596     55812.689899
#             ...
# 761     26433.595062
# 835     42955.969185
# 317     48314.869416
# 312     48099.728113
# 1085    52619.310069
# Length: 325, dtype: float64

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.820
# Model:                            OLS   Adj. R-squared (uncentered):              0.818
# Method:                 Least Squares   F-statistic:                              365.1
# Date:                Tue, 25 Jun 2024   Prob (F-statistic):                        0.00
# Time:                        20:25:18   Log-Likelihood:                         -10850.
# No. Observations:                 974   AIC:                                  2.172e+04
# Df Residuals:                     962   BIC:                                  2.178e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...
